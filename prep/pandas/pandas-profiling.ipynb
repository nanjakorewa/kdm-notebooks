# %% [markdown]
# # Pandas Profiling
# <iframe width="560" height="315" src="https://www.youtube.com/embed/TP1h9dN740k" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# [pandas-profiling github](https://github.com/pandas-profiling/pandas-profiling)
#
# `pip install pandas-profiling`などとしてインストールしてください。列の相関や欠損値、ユニーク数などの統計データをすぐに確認することができます。
#
# ## サンプルデータを読み込み

# %%
import pandas as pd
from sklearn.datasets import load_breast_cancer

df, y = load_breast_cancer(as_frame=True, return_X_y=True)
df = df.iloc[:, :10]  # １０列のみ使用、計算時間削減のため
df["y"] = y
df.head(10)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
# 7        13.71         20.83           90.20      577.9          0.11890
# 8        13.00         21.82           87.50      519.8          0.12730
# 9        12.46         24.04           83.97      475.9          0.11860
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760         0.30010              0.14710         0.2419
# ...

# %% [markdown]
# ## pandas-profilingを実行
# html以外の出力もできます、以下のドキュメント([pandas_profiling Documentation](https://pandas-profiling.github.io/pandas-profiling/docs/master/index.html))を参照してください。
#
# 出力例は <a href="./sample.html">sample.html</a> を参照してください。

# %%
# from pandas_profiling import ProfileReport
# profile = ProfileReport(df, title="sample dataset")

# htmlとして出力
# profile.to_file('sample-pandas-profiling.html')
