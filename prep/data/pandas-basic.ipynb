# %% [markdown]
# # pandasでよく使う操作
# 使用しているデータセットについては『[総務省のデータ](./サンプルデータ.ipynb)』の項を参照してください。
# pandasの操作について、一番初めに[pandasドキュメントのチュートリアル](https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html)を一度見ると一通りの操作がわかると思います。
#
#
# ## データを読み込む
# - テーブル全体 ＝ DataFrameと呼ぶ
# - テーブルの各行 ＝ rowと呼ぶ
# - テーブルの各列 ＝ columnと呼び、Seriesというデータに収まっている

# %%
import pandas as pd

df = pd.read_csv("./z-001.csv")
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1  平成21年度  平成22年度  平成23年度  平成24年度  平成25年度  平成26年度  \
# 0           2    社会保障関係費    29.8    31.2    32.7    32.7    31.8    32.8
# 1           3        公債費    18.9    20.3    19.8    20.9    20.9    21.4
# 2           4        機関費    11.9    12.5    11.7    10.6    11.8    11.7
# 3           5        教育費    11.7    11.9    11.7    12.1    11.6    11.7
# 4           6  国土保全及び開発費    12.0    11.3    10.6    10.2    10.9    10.5
#
#    平成27年度  平成28年度  平成29年度  平成30年度  令和元年度
# 0    33.7    34.4    34.6    34.4   34.7
# 1    21.3    20.6    20.9    20.6   20.0
# 2    11.8    11.4    11.5    11.9   11.8
# 3    11.7    11.7    11.8    11.8   11.9
# 4     9.9    10.4    10.5    10.5   10.8

# %% [markdown]
# # データを整形する
# ```{hint}
# [pandas.DataFrame](https://pandas.pydata.org/docs/reference/frame.html)
# ```
# 列名の変更・重複の除去・型の変更・欠損の置き換えなどを実行する。データ全体の欠損を置き換えたり、データの各列・行ごとに一括で統計量を求めるメソッドが用意されている。
#
# ```
# pandas.DataFrame.mad
# pandas.DataFrame.max
# pandas.DataFrame.mean
# pandas.DataFrame.median
# pandas.DataFrame.min
# pandas.DataFrame.mode
# ```

# %% [markdown]
# ## 欠損や余分なデータへの対応

# %%
df = df.fillna(0)  # 欠損を0に置き換え
df = df.drop(["Unnamed: 0"], axis=1)  #  'Unnamed: 0'列を削除
df.columns = df.columns.str.replace("Unnamed: ", "列")  # 列名の Unnamed を別の文字列に置換
df = df.applymap(
    lambda x: int(x) if type(x) == float else x
)  # 数値データならば全て整数にするような関数を全体に適用する

df.head()
# Out:
#           列1  平成21年度  平成22年度  平成23年度  平成24年度  平成25年度  平成26年度  平成27年度  平成28年度  \
# 0    社会保障関係費      29      31      32      32      31      32      33      34
# 1        公債費      18      20      19      20      20      21      21      20
# 2        機関費      11      12      11      10      11      11      11      11
# 3        教育費      11      11      11      12      11      11      11      11
# 4  国土保全及び開発費      12      11      10      10      10      10       9      10
#
#    平成29年度  平成30年度  令和元年度
# 0      34      34     34
# 1      20      20     20
# 2      11      11     11
# 3      11      11     11
# 4      10      10     10

# %% [markdown]
# ## データを絞り込む

# %%
# 平成21年度 > 15となるような行のみを抽出します
df.query("平成21年度 > 15")
# Out:
#         列1  平成21年度  平成22年度  平成23年度  平成24年度  平成25年度  平成26年度  平成27年度  平成28年度  \
# 0  社会保障関係費      29      31      32      32      31      32      33      34
# 1      公債費      18      20      19      20      20      21      21      20
#
#    平成29年度  平成30年度  令和元年度
# 0      34      34     34
# 1      20      20     20

# %%
# 平成21年度 > 10 & 平成22年度 < 15 となるような行のみを抽出します
df.query("平成21年度 > 10 & 平成22年度 < 15")
# Out:
#           列1  平成21年度  平成22年度  平成23年度  平成24年度  平成25年度  平成26年度  平成27年度  平成28年度  \
# 2        機関費      11      12      11      10      11      11      11      11
# 3        教育費      11      11      11      12      11      11      11      11
# 4  国土保全及び開発費      12      11      10      10      10      10       9      10
#
#    平成29年度  平成30年度  令和元年度
# 2      11      11     11
# 3      11      11     11
# 4      10      10     10

# %% [markdown]
# ## データの列ごとの統計量を算出する

# %%
# 数値の列のみに絞り込む
df_num = df.select_dtypes("number")

# 列をリストにする関数
def concat_str(series: pd.Series) -> list:
    """列に含まれるデータをリストにする"""
    return [s for s in series]


# 列ごとの統計量を求める、指定した関数にデータを渡して実行することもできる
df_num.agg(["min", "max", "median", "mean", concat_str])
# Out:
#                              平成21年度                   平成22年度  \
# min                               9                        8
# max                              29                       31
# median                         11.5                     11.5
# mean                           15.0                     15.5
# concat_str  [29, 18, 11, 11, 12, 9]  [31, 20, 12, 11, 11, 8]
#
#                              平成23年度                   平成24年度  \
# min                               9                        8
# max                              32                       32
# median                         11.0                     11.0
# mean                      15.333333                15.333333
# concat_str  [32, 19, 11, 11, 10, 9]  [32, 20, 10, 12, 10, 8]
#
#                              平成25年度                   平成26年度  \
# min                               7                        6
# max                              31                       32
# median                         11.0                     11.0
# mean                           15.0                15.166667
# concat_str  [31, 20, 11, 11, 10, 7]  [32, 21, 11, 11, 10, 6]
#
#                             平成27年度                   平成28年度  \
# min                              6                        6
# max                             33                       34
# median                        11.0                     11.0
# mean                     15.166667                15.333333
# concat_str  [33, 21, 11, 11, 9, 6]  [34, 20, 11, 11, 10, 6]
#
#                              平成29年度                   平成30年度  \
# min                               6                        6
# max                              34                       34
# median                         11.0                     11.0
# mean                      15.333333                15.333333
# concat_str  [34, 20, 11, 11, 10, 6]  [34, 20, 11, 11, 10, 6]
#
#                               令和元年度
# min                               6
# max                              34
# median                         11.0
# mean                      15.333333
# concat_str  [34, 20, 11, 11, 10, 6]

# %% [markdown]
# # 列ごとの統計量を求める
# ```{hint}
# [pandas.Series](https://pandas.pydata.org/docs/reference/series.html)
# ```
# ドキュメントにメソッドとプロパティの一覧が記載されている、`min`や`max`などを始めとして様々な計算を簡単に実行することができる。欠損が含まれているかどうかを示すプロパティも定義されている。

# %% [markdown]
# ## 数値データ

# %%
平成21年の列 = df["平成21年度"]
print(平成21年の列)
# Out:
# 0    29
# 1    18
# 2    11
# 3    11
# 4    12
# 5     9
# Name: 平成21年度, dtype: int64

# %%
print(f" min: {平成21年の列.min()}")
print(f" max: {平成21年の列.max()}")
print(f" median: {平成21年の列.median()}")
print(f" dtypes(データ型): {平成21年の列.dtypes}")
print(f" hasnans(欠損の有無): {平成21年の列.hasnans}")
# Out:
#  min: 9
#  max: 29
#  median: 11.5
#  dtypes(データ型): int64
#  hasnans(欠損の有無): False

# %% [markdown]
# ## 文字列データ
# もしも文字列に対する操作が用意されているか全く見当がつかない場合、
# 例えば文字列の出現回数を知りたい時はドキュメントで「count value」などと検索すれば、
#
# - Categorical data
# - How to calculate summary statistics?
# - pandas.DataFrame.count
# - pandas.Series.count
#
# などのページが出てきます。そして、[pandas.DataFrame.count](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html?highlight=count%20value%20column)などを見れば
# 『**See also**(こちらもご覧下さい)』の欄に`DataFrame.value_counts`へのリンクがあります。`value_counts`でドキュメントを検索すれば [pandas.Series.value_counts](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html?highlight=value_counts#pandas.Series.value_counts)が見つかり、これを使えば文字列の出現回数が求められることが分かります。

# %%
df["平成21年度"].value_counts()
# Out:
# 11    2
# 29    1
# 18    1
# 12    1
# 9     1
# Name: 平成21年度, dtype: int64
